# %% [markdown]
# Adding all the libraries necessary for the project

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import os

# %%
os.listdir(os.getcwd())
df=pd.read_csv('life.csv')

# %%
df.head(3)
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 0             62     0.01               71.279624         65.0      1154
# 1             64     0.01               73.523582         62.0       492
# 2             66     0.01               73.219243         64.0       430
#
#      ...      Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  \
# 0    ...        6.0               8.16         65.0        0.1  584.259210
# 1    ...       58.0               8.18         62.0        0.1  612.696514
# 2    ...       62.0               8.13         64.0        0.1  631.744976
#
#    Population   thinness  1-19 years   thinness 5-9 years  \
# 0  33736494.0                   17.2                 17.3
# 1    327582.0                   17.5                 17.5
# 2  31731688.0                   17.7                 17.7
#
#    Income composition of resources  Schooling
# 0                            0.479       10.1
# 1                            0.476       10.0
# 2                            0.470        9.9
#
# [3 rows x 22 columns]

# %%
df.isnull().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
#  BMI                                34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                448
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %%
print(len(df))
# Out:
# 2938

# %%
df.describe()
# Out:
#               Year  Life expectancy   Adult Mortality  infant deaths  \
# count  2938.000000       2928.000000      2928.000000    2938.000000
# mean   2007.518720         69.224932       164.796448      30.303948
# std       4.613841          9.523867       124.292079     117.926501
# min    2000.000000         36.300000         1.000000       0.000000
# 25%    2004.000000         63.100000        74.000000       0.000000
# 50%    2008.000000         72.100000       144.000000       3.000000
# 75%    2012.000000         75.700000       228.000000      22.000000
# max    2015.000000         89.000000       723.000000    1800.000000
#
#            Alcohol  percentage expenditure  Hepatitis B       Measles   \
# count  2744.000000             2938.000000  2385.000000    2938.000000
# mean      4.602861              738.251295    80.940461    2419.592240
# std       4.052413             1987.914858    25.070016   11467.272489
# min       0.010000                0.000000     1.000000       0.000000
# 25%       0.877500                4.685343    77.000000       0.000000
# 50%       3.755000               64.912906    92.000000      17.000000
# 75%       7.702500              441.534144    97.000000     360.250000
# max      17.870000            19479.911610    99.000000  212183.000000
#
#               BMI   under-five deaths         Polio  Total expenditure  \
# count  2904.000000         2938.000000  2919.000000         2712.00000
# mean     38.321247           42.035739    82.550188            5.93819
# std      20.044034          160.445548    23.428046            2.49832
# min       1.000000            0.000000     3.000000            0.37000
# 25%      19.300000            0.000000    78.000000            4.26000
# 50%      43.500000            4.000000    93.000000            5.75500
# 75%      56.200000           28.000000    97.000000            7.49250
# max      87.300000         2500.000000    99.000000           17.60000
#
#        Diphtheria      HIV/AIDS            GDP    Population  \
# count  2919.000000  2938.000000    2490.000000  2.286000e+03
# mean     82.324084     1.742103    7483.158469  1.275338e+07
# std      23.716912     5.077785   14270.169342  6.101210e+07
# min       2.000000     0.100000       1.681350  3.400000e+01
# 25%      78.000000     0.100000     463.935626  1.957932e+05
# 50%      93.000000     0.100000    1766.947595  1.386542e+06
# 75%      97.000000     0.800000    5910.806335  7.420359e+06
# max      99.000000    50.600000  119172.741800  1.293859e+09
#
#         thinness  1-19 years   thinness 5-9 years  \
# count            2904.000000          2904.000000
# mean                4.839704             4.870317
# std                 4.420195             4.508882
# min                 0.100000             0.100000
# 25%                 1.600000             1.500000
# 50%                 3.300000             3.300000
# 75%                 7.200000             7.200000
# max                27.700000            28.600000
#
#        Income composition of resources    Schooling
# count                      2771.000000  2775.000000
# mean                          0.627551    11.992793
# std                           0.210904     3.358920
# min                           0.000000     0.000000
# 25%                           0.493000    10.100000
# 50%                           0.677000    12.300000
# 75%                           0.779000    14.300000
# max                           0.948000    20.700000

# %%
df.dtypes
# Out:
# Country                             object
# Year                                 int64
# Status                              object
# Life expectancy                    float64
# Adult Mortality                    float64
# infant deaths                        int64
# Alcohol                            float64
# percentage expenditure             float64
# Hepatitis B                        float64
# Measles                              int64
#  BMI                               float64
# under-five deaths                    int64
# Polio                              float64
# Total expenditure                  float64
# Diphtheria                         float64
#  HIV/AIDS                          float64
# GDP                                float64
# Population                         float64
#  thinness  1-19 years              float64
#  thinness 5-9 years                float64
# Income composition of resources    float64
# Schooling                          float64
# dtype: object

# %%
df=df.dropna(axis=0)

# %%
len(df)
# Out:
# 1649

# %%
from sklearn.model_selection import train_test_split

# %%
r=df.groupby('Country').count()
print(r)
# Out:
#                           Year  Status  Life expectancy   Adult Mortality  \
# Country
# Afghanistan                 16      16                16               16
# Albania                     16      16                16               16
# Algeria                     11      11                11               11
# Angola                       8       8                 8                8
# Argentina                   13      13                13               13
# Armenia                     15      15                15               15
# Australia                   14      14                14               14
# Austria                     15      15                15               15
# Azerbaijan                  13      13                13               13
# Bangladesh                  12      12                12               12
# Belarus                     15      15                15               15
# Belgium                     15      15                15               15
# Belize                      15      15                15               15
# Benin                       13      13                13               13
# Bhutan                      15      15                15               15
# Bosnia and Herzegovina      11      11                11               11
# Botswana                    15      15                15               15
# Brazil                      15      15                15               15
# Bulgaria                    15      15                15               15
# Burkina Faso                 9       9                 9                9
# Burundi                     11      11                11               11
# Cabo Verde                  13      13                13               13
# Cambodia                     9       9                 9                9
# Cameroon                    10      10                10               10
# Canada                      12      12                12               12
# Central African Republic     6       6                 6                6
# Chad                         7       7                 7                7
# Chile                        9       9                 9                9
# China                       15      15                15               15
# Colombia                    15      15                15               15
# ...                        ...     ...               ...              ...
# Samoa                       15      15                15               15
# Sao Tome and Principe       12      12                12               12
# Senegal                     11      11                11               11
# Serbia                      11      11                11               11
# Seychelles                  15      15                15               15
# Sierra Leone                 8       8                 8                8
# Solomon Islands             15      15                15               15
# South Africa                15      15                15               15
# Spain                       15      15                15               15
# Sri Lanka                   12      12                12               12
# Suriname                    10      10                10               10
# Swaziland                   15      15                15               15
# Sweden                       4       4                 4                4
# Syrian Arab Republic         8       8                 8                8
# Tajikistan                  13      13                13               13
# Thailand                    15      15                15               15
# Timor-Leste                  7       7                 7                7
# Togo                         7       7                 7                7
# Tonga                       15      15                15               15
# Trinidad and Tobago         13      13                13               13
# Tunisia                     15      15                15               15
# Turkey                      15      15                15               15
# Turkmenistan                13      13                13               13
# Uganda                      13      13                13               13
# Ukraine                     15      15                15               15
# Uruguay                     15      15                15               15
# Uzbekistan                  13      13                13               13
# Vanuatu                     15      15                15               15
# Zambia                      10      10                10               10
# Zimbabwe                    15      15                15               15
#
#                           infant deaths  Alcohol  percentage expenditure  \
# Country
# Afghanistan                          16       16                      16
# Albania                              16       16                      16
# Algeria                              11       11                      11
# Angola                                8        8                       8
# Argentina                            13       13                      13
# Armenia                              15       15                      15
# Australia                            14       14                      14
# Austria                              15       15                      15
# Azerbaijan                           13       13                      13
# Bangladesh                           12       12                      12
# Belarus                              15       15                      15
# Belgium                              15       15                      15
# Belize                               15       15                      15
# Benin                                13       13                      13
# Bhutan                               15       15                      15
# Bosnia and Herzegovina               11       11                      11
# Botswana                             15       15                      15
# Brazil                               15       15                      15
# Bulgaria                             15       15                      15
# Burkina Faso                          9        9                       9
# Burundi                              11       11                      11
# Cabo Verde                           13       13                      13
# Cambodia                              9        9                       9
# Cameroon                             10       10                      10
# Canada                               12       12                      12
# Central African Republic              6        6                       6
# Chad                                  7        7                       7
# Chile                                 9        9                       9
# China                                15       15                      15
# Colombia                             15       15                      15
# ...                                 ...      ...                     ...
# Samoa                                15       15                      15
# Sao Tome and Principe                12       12                      12
# Senegal                              11       11                      11
# Serbia                               11       11                      11
# Seychelles                           15       15                      15
# Sierra Leone                          8        8                       8
# Solomon Islands                      15       15                      15
# South Africa                         15       15                      15
# Spain                                15       15                      15
# Sri Lanka                            12       12                      12
# Suriname                             10       10                      10
# Swaziland                            15       15                      15
# Sweden                                4        4                       4
# Syrian Arab Republic                  8        8                       8
# Tajikistan                           13       13                      13
# Thailand                             15       15                      15
# Timor-Leste                           7        7                       7
# Togo                                  7        7                       7
# Tonga                                15       15                      15
# Trinidad and Tobago                  13       13                      13
# Tunisia                              15       15                      15
# Turkey                               15       15                      15
# Turkmenistan                         13       13                      13
# Uganda                               13       13                      13
# Ukraine                              15       15                      15
# Uruguay                              15       15                      15
# Uzbekistan                           13       13                      13
# Vanuatu                              15       15                      15
# Zambia                               10       10                      10
# Zimbabwe                             15       15                      15
#
#                           Hepatitis B  Measles    BMI     ...      Polio  \
# Country                                                   ...
# Afghanistan                        16        16     16    ...         16
# Albania                            16        16     16    ...         16
# Algeria                            11        11     11    ...         11
# Angola                              8         8      8    ...          8
# Argentina                          13        13     13    ...         13
# Armenia                            15        15     15    ...         15
# Australia                          14        14     14    ...         14
# Austria                            15        15     15    ...         15
# Azerbaijan                         13        13     13    ...         13
# Bangladesh                         12        12     12    ...         12
# Belarus                            15        15     15    ...         15
# Belgium                            15        15     15    ...         15
# Belize                             15        15     15    ...         15
# Benin                              13        13     13    ...         13
# Bhutan                             15        15     15    ...         15
# Bosnia and Herzegovina             11        11     11    ...         11
# Botswana                           15        15     15    ...         15
# Brazil                             15        15     15    ...         15
# Bulgaria                           15        15     15    ...         15
# Burkina Faso                        9         9      9    ...          9
# Burundi                            11        11     11    ...         11
# Cabo Verde                         13        13     13    ...         13
# Cambodia                            9         9      9    ...          9
# Cameroon                           10        10     10    ...         10
# Canada                             12        12     12    ...         12
# Central African Republic            6         6      6    ...          6
# Chad                                7         7      7    ...          7
# Chile                               9         9      9    ...          9
# China                              15        15     15    ...         15
# Colombia                           15        15     15    ...         15
# ...                               ...       ...    ...    ...        ...
# Samoa                              15        15     15    ...         15
# Sao Tome and Principe              12        12     12    ...         12
# Senegal                            11        11     11    ...         11
# Serbia                             11        11     11    ...         11
# Seychelles                         15        15     15    ...         15
# Sierra Leone                        8         8      8    ...          8
# Solomon Islands                    15        15     15    ...         15
# South Africa                       15        15     15    ...         15
# Spain                              15        15     15    ...         15
# Sri Lanka                          12        12     12    ...         12
# Suriname                           10        10     10    ...         10
# Swaziland                          15        15     15    ...         15
# Sweden                              4         4      4    ...          4
# Syrian Arab Republic                8         8      8    ...          8
# Tajikistan                         13        13     13    ...         13
# Thailand                           15        15     15    ...         15
# Timor-Leste                         7         7      7    ...          7
# Togo                                7         7      7    ...          7
# Tonga                              15        15     15    ...         15
# Trinidad and Tobago                13        13     13    ...         13
# Tunisia                            15        15     15    ...         15
# Turkey                             15        15     15    ...         15
# Turkmenistan                       13        13     13    ...         13
# Uganda                             13        13     13    ...         13
# Ukraine                            15        15     15    ...         15
# Uruguay                            15        15     15    ...         15
# Uzbekistan                         13        13     13    ...         13
# Vanuatu                            15        15     15    ...         15
# Zambia                             10        10     10    ...         10
# Zimbabwe                           15        15     15    ...         15
#
#                           Total expenditure  Diphtheria    HIV/AIDS  GDP  \
# Country
# Afghanistan                              16           16         16   16
# Albania                                  16           16         16   16
# Algeria                                  11           11         11   11
# Angola                                    8            8          8    8
# Argentina                                13           13         13   13
# Armenia                                  15           15         15   15
# Australia                                14           14         14   14
# Austria                                  15           15         15   15
# Azerbaijan                               13           13         13   13
# Bangladesh                               12           12         12   12
# Belarus                                  15           15         15   15
# Belgium                                  15           15         15   15
# Belize                                   15           15         15   15
# Benin                                    13           13         13   13
# Bhutan                                   15           15         15   15
# Bosnia and Herzegovina                   11           11         11   11
# Botswana                                 15           15         15   15
# Brazil                                   15           15         15   15
# Bulgaria                                 15           15         15   15
# Burkina Faso                              9            9          9    9
# Burundi                                  11           11         11   11
# Cabo Verde                               13           13         13   13
# Cambodia                                  9            9          9    9
# Cameroon                                 10           10         10   10
# Canada                                   12           12         12   12
# Central African Republic                  6            6          6    6
# Chad                                      7            7          7    7
# Chile                                     9            9          9    9
# China                                    15           15         15   15
# Colombia                                 15           15         15   15
# ...                                     ...          ...        ...  ...
# Samoa                                    15           15         15   15
# Sao Tome and Principe                    12           12         12   12
# Senegal                                  11           11         11   11
# Serbia                                   11           11         11   11
# Seychelles                               15           15         15   15
# Sierra Leone                              8            8          8    8
# Solomon Islands                          15           15         15   15
# South Africa                             15           15         15   15
# Spain                                    15           15         15   15
# Sri Lanka                                12           12         12   12
# Suriname                                 10           10         10   10
# Swaziland                                15           15         15   15
# Sweden                                    4            4          4    4
# Syrian Arab Republic                      8            8          8    8
# Tajikistan                               13           13         13   13
# Thailand                                 15           15         15   15
# Timor-Leste                               7            7          7    7
# Togo                                      7            7          7    7
# Tonga                                    15           15         15   15
# Trinidad and Tobago                      13           13         13   13
# Tunisia                                  15           15         15   15
# Turkey                                   15           15         15   15
# Turkmenistan                             13           13         13   13
# Uganda                                   13           13         13   13
# Ukraine                                  15           15         15   15
# Uruguay                                  15           15         15   15
# Uzbekistan                               13           13         13   13
# Vanuatu                                  15           15         15   15
# Zambia                                   10           10         10   10
# Zimbabwe                                 15           15         15   15
#
#                           Population   thinness  1-19 years  \
# Country
# Afghanistan                       16                     16
# Albania                           16                     16
# Algeria                           11                     11
# Angola                             8                      8
# Argentina                         13                     13
# Armenia                           15                     15
# Australia                         14                     14
# Austria                           15                     15
# Azerbaijan                        13                     13
# Bangladesh                        12                     12
# Belarus                           15                     15
# Belgium                           15                     15
# Belize                            15                     15
# Benin                             13                     13
# Bhutan                            15                     15
# Bosnia and Herzegovina            11                     11
# Botswana                          15                     15
# Brazil                            15                     15
# Bulgaria                          15                     15
# Burkina Faso                       9                      9
# Burundi                           11                     11
# Cabo Verde                        13                     13
# Cambodia                           9                      9
# Cameroon                          10                     10
# Canada                            12                     12
# Central African Republic           6                      6
# Chad                               7                      7
# Chile                              9                      9
# China                             15                     15
# Colombia                          15                     15
# ...                              ...                    ...
# Samoa                             15                     15
# Sao Tome and Principe             12                     12
# Senegal                           11                     11
# Serbia                            11                     11
# Seychelles                        15                     15
# Sierra Leone                       8                      8
# Solomon Islands                   15                     15
# South Africa                      15                     15
# Spain                             15                     15
# Sri Lanka                         12                     12
# Suriname                          10                     10
# Swaziland                         15                     15
# Sweden                             4                      4
# Syrian Arab Republic               8                      8
# Tajikistan                        13                     13
# Thailand                          15                     15
# Timor-Leste                        7                      7
# Togo                               7                      7
# Tonga                             15                     15
# Trinidad and Tobago               13                     13
# Tunisia                           15                     15
# Turkey                            15                     15
# Turkmenistan                      13                     13
# Uganda                            13                     13
# Ukraine                           15                     15
# Uruguay                           15                     15
# Uzbekistan                        13                     13
# Vanuatu                           15                     15
# Zambia                            10                     10
# Zimbabwe                          15                     15
#
#                            thinness 5-9 years  \
# Country
# Afghanistan                                16
# Albania                                    16
# Algeria                                    11
# Angola                                      8
# Argentina                                  13
# Armenia                                    15
# Australia                                  14
# Austria                                    15
# Azerbaijan                                 13
# Bangladesh                                 12
# Belarus                                    15
# Belgium                                    15
# Belize                                     15
# Benin                                      13
# Bhutan                                     15
# Bosnia and Herzegovina                     11
# Botswana                                   15
# Brazil                                     15
# Bulgaria                                   15
# Burkina Faso                                9
# Burundi                                    11
# Cabo Verde                                 13
# Cambodia                                    9
# Cameroon                                   10
# Canada                                     12
# Central African Republic                    6
# Chad                                        7
# Chile                                       9
# China                                      15
# Colombia                                   15
# ...                                       ...
# Samoa                                      15
# Sao Tome and Principe                      12
# Senegal                                    11
# Serbia                                     11
# Seychelles                                 15
# Sierra Leone                                8
# Solomon Islands                            15
# South Africa                               15
# Spain                                      15
# Sri Lanka                                  12
# Suriname                                   10
# Swaziland                                  15
# Sweden                                      4
# Syrian Arab Republic                        8
# Tajikistan                                 13
# Thailand                                   15
# Timor-Leste                                 7
# Togo                                        7
# Tonga                                      15
# Trinidad and Tobago                        13
# Tunisia                                    15
# Turkey                                     15
# Turkmenistan                               13
# Uganda                                     13
# Ukraine                                    15
# Uruguay                                    15
# Uzbekistan                                 13
# Vanuatu                                    15
# Zambia                                     10
# Zimbabwe                                   15
#
#                           Income composition of resources  Schooling
# Country
# Afghanistan                                            16         16
# Albania                                                16         16
# Algeria                                                11         11
# Angola                                                  8          8
# Argentina                                              13         13
# Armenia                                                15         15
# Australia                                              14         14
# Austria                                                15         15
# Azerbaijan                                             13         13
# Bangladesh                                             12         12
# Belarus                                                15         15
# Belgium                                                15         15
# Belize                                                 15         15
# Benin                                                  13         13
# Bhutan                                                 15         15
# Bosnia and Herzegovina                                 11         11
# Botswana                                               15         15
# Brazil                                                 15         15
# Bulgaria                                               15         15
# Burkina Faso                                            9          9
# Burundi                                                11         11
# Cabo Verde                                             13         13
# Cambodia                                                9          9
# Cameroon                                               10         10
# Canada                                                 12         12
# Central African Republic                                6          6
# Chad                                                    7          7
# Chile                                                   9          9
# China                                                  15         15
# Colombia                                               15         15
# ...                                                   ...        ...
# Samoa                                                  15         15
# Sao Tome and Principe                                  12         12
# Senegal                                                11         11
# Serbia                                                 11         11
# Seychelles                                             15         15
# Sierra Leone                                            8          8
# Solomon Islands                                        15         15
# South Africa                                           15         15
# Spain                                                  15         15
# Sri Lanka                                              12         12
# Suriname                                               10         10
# Swaziland                                              15         15
# Sweden                                                  4          4
# Syrian Arab Republic                                    8          8
# Tajikistan                                             13         13
# Thailand                                               15         15
# Timor-Leste                                             7          7
# Togo                                                    7          7
# Tonga                                                  15         15
# Trinidad and Tobago                                    13         13
# Tunisia                                                15         15
# Turkey                                                 15         15
# Turkmenistan                                           13         13
# Uganda                                                 13         13
# Ukraine                                                15         15
# Uruguay                                                15         15
# Uzbekistan                                             13         13
# Vanuatu                                                15         15
# Zambia                                                 10         10
# Zimbabwe                                               15         15
#
# [133 rows x 21 columns]

# %%
r=df.groupby('Status').count()
print(r)
# Out:
#             Country  Year  Life expectancy   Adult Mortality  infant deaths  \
# Status
# Developed       242   242               242              242            242
# Developing     1407  1407              1407             1407           1407
#
#             Alcohol  percentage expenditure  Hepatitis B  Measles    BMI   \
# Status
# Developed       242                     242          242       242    242
# Developing     1407                    1407         1407      1407   1407
#
#               ...      Polio  Total expenditure  Diphtheria    HIV/AIDS   GDP  \
# Status        ...
# Developed     ...        242                242          242        242   242
# Developing    ...       1407               1407         1407       1407  1407
#
#             Population   thinness  1-19 years   thinness 5-9 years  \
# Status
# Developed          242                    242                  242
# Developing        1407                   1407                 1407
#
#             Income composition of resources  Schooling
# Status
# Developed                               242        242
# Developing                             1407       1407
#
# [2 rows x 21 columns]

# %%
df.plot(x='Status', y=['Adult Mortality'], figsize=(10,5), grid=True)

# %%
df.columns=df.columns.str.replace(' ','_')

# %%
df.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Life_expectancy_', 'Adult_Mortality',
#        'infant_deaths', 'Alcohol', 'percentage_expenditure', 'Hepatitis_B',
#        'Measles_', '_BMI_', 'under-five_deaths_', 'Polio', 'Total_expenditure',
#        'Diphtheria_', '_HIV/AIDS', 'GDP', 'Population',
#        '_thinness__1-19_years', '_thinness_5-9_years',
#        'Income_composition_of_resources', 'Schooling'],
#       dtype='object')

# %%
plt.scatter(df.Schooling, df.Life_expectancy_)
plt.show()

# %%
import seaborn as sns
plt.figure(figsize=(15,10))
corr = df.corr()
sns.heatmap(corr, 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)

# %%
plt.scatter(df.Income_composition_of_resources, df.Life_expectancy_)
plt.show()

# %%
plt.scatter(df._BMI_, df.Life_expectancy_)
plt.show()

# %%
plt.scatter(df.Alcohol, df.Life_expectancy_)
plt.show()

# %%
plt.scatter(df.Adult_Mortality, df.Life_expectancy_)
plt.show()

# %%
X = pd.DataFrame(np.c_[df['Schooling'], df['Adult_Mortality']], columns = ['Income_composition_of_resources','Schooling'])
Y = df['Life_expectancy_']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state=5)
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
# Out:
# (1319, 2)
# (330, 2)
# (1319,)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
lin_model = LinearRegression()
lin_model.fit(X_train, Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
y_train_predict = lin_model.predict(X_train)
rmse = (np.sqrt(mean_squared_error(Y_train, y_train_predict)))
r2 = r2_score(Y_train, y_train_predict)

# %%
print("The model performance for training set")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
print("\n")

# model evaluation for testing set
y_test_predict = lin_model.predict(X_test)
rmse = (np.sqrt(mean_squared_error(Y_test, y_test_predict)))
r2 = r2_score(Y_test, y_test_predict)

print("The model performance for testing set")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
# Out:
# The model performance for training set
# --------------------------------------
# RMSE is 4.670239136687515
# R2 score is 0.7203757599908633
#
#
# The model performance for testing set
# --------------------------------------
# RMSE is 4.591682629567791
# R2 score is 0.7168530654018644
